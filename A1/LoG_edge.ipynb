# %% [markdown]
# ## 2.2 - Laplacian of Gaussian
# #### 1. Apply a 5×5 Laplacian of Gaussian edge detector to the image 'woman'.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# load original image
original_img = cv2.imread('woman.png', cv2.IMREAD_GRAYSCALE)

# display original image
plt.axis('off')
plt.imshow(original_img, cmap='gray')
plt.title("Original Image")
plt.show()

# %%
# remove noise with gaussian filter
gaussian_img = cv2.GaussianBlur(sharpened_img,(3,3),2)

# apply laplacian edge detection
result = cv2.Laplacian(gaussian_img,cv2.CV_64F)

# display result
plt.axis('off')
plt.imshow(result, cmap='gray')
plt.title("Laplacian Edge Detection")
plt.show()
